# %%
import os
import cv2
import numpy as np
import tkinter as tk
from tkinter import filedialog
from tkinter import messagebox
from PIL import Image, ImageTk
import tensorflow as tf
from tensorflow.keras.applications import VGG16
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import threading  # Used for running classification in the background

# --------------------------- #
# 🔹 Define Paths & Parameters
# --------------------------- #
train_dir = "output/train"
val_dir = "output/val"
input_shape = (224, 224, 3)
batch_size = 32
NUM_CLASSES = 5  # Updated number of traffic sign classes

# --------------------------- #
# 🔹 Data Preparation (for VGG16)
# --------------------------- #
train_datagen = ImageDataGenerator(rescale=1.0/255.0)
val_datagen = ImageDataGenerator(rescale=1.0/255.0)

train_data = train_datagen.flow_from_directory(train_dir, target_size=(224, 224), 
                                               batch_size=batch_size, class_mode='categorical')
val_data = val_datagen.flow_from_directory(val_dir, target_size=(224, 224), 
                                           batch_size=batch_size, class_mode='categorical')

# --------------------------- #
# 🔹 Function to Create VGG16 Model
# --------------------------- #
def create_vgg16_model():
    base_model = VGG16(weights="imagenet", include_top=False, input_shape=input_shape)
    base_model.trainable = False  # Freeze pre-trained layers

    x = GlobalAveragePooling2D()(base_model.output)
    x = Dense(256, activation="relu")(x)
    x = Dropout(0.5)(x)
    output = Dense(NUM_CLASSES, activation="softmax")(x)  # Ensure correct number of classes

    model = Model(inputs=base_model.input, outputs=output)
    return model

# --------------------------- #
# 🔹 Train and Save VGG16 Model (if not exists)
# --------------------------- #
vgg16_model_path = "vgg16_model.h5"

if not os.path.exists(vgg16_model_path):
    print("Training VGG16 Model... 🚀")
    vgg16_model = create_vgg16_model()
    vgg16_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
                        loss="categorical_crossentropy",
                        metrics=["accuracy"])
    
    vgg16_model.fit(train_data, epochs=30, validation_data=val_data)
    vgg16_model.save(vgg16_model_path)
    print(f"✅ VGG16 Model saved as '{vgg16_model_path}'.")
else:
    print(f"✅ Found existing model '{vgg16_model_path}', skipping training.")

# Load the trained model
vgg16_model = create_vgg16_model()
vgg16_model.load_weights(vgg16_model_path)
print("✅ VGG16 Model Loaded Successfully!")

# --------------------------- #
# 🔹 Function: Preprocess Image for VGG16
# --------------------------- #
def preprocess_for_vgg16(image):
    image = image.resize((224, 224))  # Resize image
    image = np.array(image) / 255.0  # Normalize
    image = np.expand_dims(image, axis=0)  # Expand dims for model
    return image

# --------------------------- #
# 🔹 Function: Classify Image Using VGG16
# --------------------------- #
def classify_image(image_path):
    image = Image.open(image_path)  # Open image
    processed_img = preprocess_for_vgg16(image)  # Preprocess for VGG16
    predictions = vgg16_model.predict(processed_img)  # Predict

    class_id = np.argmax(predictions)
    confidence = predictions[0][class_id]
    
    # Class labels
    class_labels = ['100_new', '200_new', '20_new', '500_new', '50_new']
    label = f"{class_labels[class_id]} ({confidence:.2f})"
    
    return label

# --------------------------- #
# 🔹 Function to Open File Dialog and Select Image
# --------------------------- #
def select_image():
    root = tk.Tk()
    root.withdraw()  # Hide the root window
    image_path = filedialog.askopenfilename(title="Select Image", filetypes=[("Image files", "*.jpg;*.jpeg;*.png")])
    return image_path

# --------------------------- #
# 🔹 Function to Display the Classification Result
# --------------------------- #
def show_classification_result(image_path):
    result_label.config(text="Processing... Please wait.", fg="black")
    
    # Run classification in a background thread to avoid blocking UI
    threading.Thread(target=run_classification, args=(image_path,)).start()

# --------------------------- #
# 🔹 Function to Run Classification in the Background
# --------------------------- #
def run_classification(image_path):
    try:
        # Classify the uploaded image
        result = classify_image(image_path)
        
        # Update the result label in the main thread
        result_label.config(text=f"Prediction: {result}", fg="green")
        
    except Exception as e:
        # In case of error, display the error message
        result_label.config(text=f"Error: {str(e)}", fg="red")

# --------------------------- #
# 🔹 Function to Load and Display Image in Tkinter
# --------------------------- #
def load_image(image_path):
    image = Image.open(image_path)
    image.thumbnail((400, 400))  # Resize for better display
    img_tk = ImageTk.PhotoImage(image)
    
    # Keep a reference of the image to prevent it from being garbage collected
    preview_label.image = img_tk  
    preview_label.config(image=img_tk)

# --------------------------- #
# 🔹 Create the Tkinter GUI
# --------------------------- #
window = tk.Tk()
window.title("Image Classification")
window.geometry("600x600")

# Create an upload button
upload_button = tk.Button(window, text="Upload Image", font=("Helvetica", 14), command=lambda: on_upload())
upload_button.pack(pady=10)

# Label to display the selected image preview
preview_label = tk.Label(window)
preview_label.pack(pady=20)

# Label for the classification result
result_label = tk.Label(window, text="Prediction: None", font=("Helvetica", 14), fg="blue")
result_label.pack(pady=20)

# --------------------------- #
# 🔹 Upload Button Logic
# --------------------------- #
def on_upload():
    image_path = select_image()
    if image_path:
        load_image(image_path)
        show_classification_result(image_path)
    else:
        messagebox.showerror("Error", "No image selected. Please upload an image.")

# Run the Tkinter event loop
window.mainloop()
# Out:
# WARNING:tensorflow:From C:\Users\Ajay\anaconda3\envs\py310\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# Found 375 images belonging to 5 classes.
# Found 100 images belonging to 5 classes.
# ✅ Found existing model 'vgg16_model.h5', skipping training.
# WARNING:tensorflow:From C:\Users\Ajay\anaconda3\envs\py310\lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From C:\Users\Ajay\anaconda3\envs\py310\lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# ✅ VGG16 Model Loaded Successfully!

# %%
import cv2
import numpy as np
import tensorflow as tf
from ultralytics import YOLO
from tensorflow.keras.applications import VGG16
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D

# Load the YOLOv8 model
yolo_model = YOLO("yolov8s.pt")
# Configure model to only detect currency notes
yolo_model.classes = [67]  # Class ID for currency notes

# --------------------------- #
# 🔹 Load VGG16 Model for Currency Classification
# --------------------------- #
def create_vgg16_model():
    input_shape = (224, 224, 3)
    base_model = VGG16(weights="imagenet", include_top=False, input_shape=input_shape)
    base_model.trainable = False

    x = GlobalAveragePooling2D()(base_model.output)
    x = Dense(256, activation="relu")(x)
    x = Dropout(0.5)(x)
    output = Dense(5, activation="softmax")(x)

    model = Model(inputs=base_model.input, outputs=output)
    return model

vgg16_model = create_vgg16_model()
vgg16_model.load_weights("vgg16_model.h5")

# Class labels for currency notes
class_labels = ['100_new', '200_new', '20_new', '500_new', '50_new']

def preprocess_for_vgg16(cropped_img):
    if cropped_img.size == 0:
        return None
    try:
        cropped_img = cv2.resize(cropped_img, (224, 224))
        cropped_img = cropped_img.astype("float32") / 255.0
        cropped_img = np.expand_dims(cropped_img, axis=0)
        return cropped_img
    except Exception as e:
        print(f"Error in preprocessing: {e}")
        return None

def is_valid_currency_note(box, conf, min_area=5000):
    # Get box dimensions
    x1, y1, x2, y2 = map(int, box.xyxy[0])
    area = (x2 - x1) * (y2 - y1)
    aspect_ratio = (x2 - x1) / (y2 - y1)
    
    # Check if the note meets our criteria
    return (conf > 0.6 and  # High confidence
            area >= min_area and  # Minimum size
            1.5 <= aspect_ratio <= 3.0)  # Typical currency note aspect ratio

def real_time_detection_and_classification():
    cap = cv2.VideoCapture(0)
    
    # Set camera properties for better performance
    cap.set(cv2.CAP_PROP_FRAME_WIDTH, 640)
    cap.set(cv2.CAP_PROP_FRAME_HEIGHT, 480)
    cap.set(cv2.CAP_PROP_FPS, 30)

    print("Starting detection. Press 'q' to quit.")

    while True:
        ret, frame = cap.read()
        if not ret:
            break

        # Create a copy for display
        display_frame = frame.copy()

        # Run YOLO detection
        results = yolo_model(frame, conf=0.5)

        best_note = None
        highest_conf = 0

        for result in results:
            boxes = result.boxes
            for box in boxes:
                conf = float(box.conf[0])
                
                # Check if this is a valid currency note with higher confidence
                if is_valid_currency_note(box, conf):
                    if conf > highest_conf:
                        highest_conf = conf
                        best_note = box

        # Process only the best detected note
        if best_note is not None:
            x1, y1, x2, y2 = map(int, best_note.xyxy[0])
            cropped_obj = frame[y1:y2, x1:x2]
            processed_img = preprocess_for_vgg16(cropped_obj)

            if processed_img is not None:
                try:
                    predictions = vgg16_model.predict(processed_img, verbose=0)
                    note_class = np.argmax(predictions)
                    note_conf = predictions[0][note_class]

                    if note_conf > 0.7:  # High confidence threshold for currency
                        label = f"{class_labels[note_class]} ({note_conf:.2f})"
                        cv2.rectangle(display_frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
                        cv2.putText(display_frame, label, (x1, y1 - 10),
                                  cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)
                except Exception as e:
                    print(f"Error in classification: {e}")

        # Add FPS counter
        fps = cap.get(cv2.CAP_PROP_FPS)
        cv2.putText(display_frame, f"FPS: {int(fps)}", (10, 30),
                    cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)

        # Display the frame
        cv2.imshow("Currency Detection", display_frame)

        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    cap.release()
    cv2.destroyAllWindows()

if __name__ == "__main__":
    real_time_detection_and_classification()
# Out:
# WARNING:tensorflow:From C:\Users\Ajay\anaconda3\envs\py310\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From C:\Users\Ajay\anaconda3\envs\py310\lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From C:\Users\Ajay\anaconda3\envs\py310\lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# Starting detection. Press 'q' to quit.
#
# 0: 480x640 1 person, 564.2ms
# Speed: 17.4ms preprocess, 564.2ms inference, 17.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 280.2ms
# Speed: 2.0ms preprocess, 280.2ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 279.1ms
# Speed: 36.1ms preprocess, 279.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 265.6ms
# Speed: 5.0ms preprocess, 265.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 255.7ms
# Speed: 7.0ms preprocess, 255.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 238.5ms
# Speed: 3.0ms preprocess, 238.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 295.7ms
# Speed: 4.0ms preprocess, 295.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 279.7ms
# Speed: 4.5ms preprocess, 279.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 255.5ms
# Speed: 5.0ms preprocess, 255.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 248.8ms
# Speed: 5.2ms preprocess, 248.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 246.9ms
# Speed: 2.0ms preprocess, 246.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 225.9ms
# Speed: 1.9ms preprocess, 225.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 253.3ms
# Speed: 2.0ms preprocess, 253.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 256.0ms
# Speed: 3.0ms preprocess, 256.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 244.7ms
# Speed: 3.0ms preprocess, 244.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 250.9ms
# Speed: 2.0ms preprocess, 250.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 222.0ms
# Speed: 4.1ms preprocess, 222.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 236.2ms
# Speed: 3.0ms preprocess, 236.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 274.3ms
# Speed: 3.0ms preprocess, 274.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 269.0ms
# Speed: 4.0ms preprocess, 269.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 244.6ms
# Speed: 3.0ms preprocess, 244.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 230.6ms
# Speed: 3.0ms preprocess, 230.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 227.0ms
# Speed: 3.5ms preprocess, 227.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 239.2ms
# Speed: 3.1ms preprocess, 239.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 223.6ms
# Speed: 3.0ms preprocess, 223.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 245.5ms
# Speed: 2.5ms preprocess, 245.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 235.1ms
# Speed: 5.1ms preprocess, 235.1ms inference, 9.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 263.9ms
# Speed: 3.0ms preprocess, 263.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 240.8ms
# Speed: 3.0ms preprocess, 240.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 243.1ms
# Speed: 2.0ms preprocess, 243.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 205.6ms
# Speed: 3.0ms preprocess, 205.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 215.1ms
# Speed: 3.0ms preprocess, 215.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 207.1ms
# Speed: 3.0ms preprocess, 207.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 210.4ms
# Speed: 3.5ms preprocess, 210.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 210.3ms
# Speed: 3.0ms preprocess, 210.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 193.8ms
# Speed: 2.0ms preprocess, 193.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 210.8ms
# Speed: 2.0ms preprocess, 210.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 223.1ms
# Speed: 3.0ms preprocess, 223.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 224.0ms
# Speed: 3.0ms preprocess, 224.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 215.6ms
# Speed: 3.0ms preprocess, 215.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 214.1ms
# Speed: 3.0ms preprocess, 214.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 217.7ms
# Speed: 3.0ms preprocess, 217.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 224.2ms
# Speed: 3.0ms preprocess, 224.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 203.1ms
# Speed: 2.0ms preprocess, 203.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 233.6ms
# Speed: 3.0ms preprocess, 233.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 201.1ms
# Speed: 3.0ms preprocess, 201.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 205.1ms
# Speed: 3.0ms preprocess, 205.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 208.0ms
# Speed: 3.0ms preprocess, 208.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 205.3ms
# Speed: 2.0ms preprocess, 205.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 203.1ms
# Speed: 3.0ms preprocess, 203.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 204.1ms
# Speed: 2.0ms preprocess, 204.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 196.1ms
# Speed: 5.0ms preprocess, 196.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 196.0ms
# Speed: 3.0ms preprocess, 196.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 209.1ms
# Speed: 3.0ms preprocess, 209.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 210.1ms
# Speed: 2.0ms preprocess, 210.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 227.1ms
# Speed: 4.6ms preprocess, 227.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 207.4ms
# Speed: 3.0ms preprocess, 207.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 201.1ms
# Speed: 3.0ms preprocess, 201.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 198.1ms
# Speed: 3.0ms preprocess, 198.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 202.1ms
# Speed: 6.0ms preprocess, 202.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 199.0ms
# Speed: 3.0ms preprocess, 199.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 200.1ms
# Speed: 3.0ms preprocess, 200.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 201.4ms
# Speed: 3.0ms preprocess, 201.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 206.6ms
# Speed: 3.0ms preprocess, 206.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 198.1ms
# Speed: 3.0ms preprocess, 198.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 196.0ms
# Speed: 3.0ms preprocess, 196.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 212.6ms
# Speed: 3.0ms preprocess, 212.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 204.1ms
# Speed: 3.0ms preprocess, 204.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 204.1ms
# Speed: 2.0ms preprocess, 204.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 201.1ms
# Speed: 3.0ms preprocess, 201.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 194.1ms
# Speed: 3.0ms preprocess, 194.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 198.1ms
# Speed: 6.0ms preprocess, 198.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 198.1ms
# Speed: 3.0ms preprocess, 198.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 202.0ms
# Speed: 3.0ms preprocess, 202.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 207.1ms
# Speed: 3.0ms preprocess, 207.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 241.6ms
# Speed: 3.0ms preprocess, 241.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 222.1ms
# Speed: 3.0ms preprocess, 222.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 227.1ms
# Speed: 3.0ms preprocess, 227.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 221.6ms
# Speed: 3.0ms preprocess, 221.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 217.4ms
# Speed: 4.0ms preprocess, 217.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 223.1ms
# Speed: 2.0ms preprocess, 223.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 218.1ms
# Speed: 3.0ms preprocess, 218.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 212.7ms
# Speed: 3.0ms preprocess, 212.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 219.2ms
# Speed: 2.0ms preprocess, 219.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 209.1ms
# Speed: 3.0ms preprocess, 209.1ms inference, 9.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 218.1ms
# Speed: 2.0ms preprocess, 218.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 224.7ms
# Speed: 4.0ms preprocess, 224.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 220.7ms
# Speed: 2.0ms preprocess, 220.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 233.2ms
# Speed: 3.0ms preprocess, 233.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 213.8ms
# Speed: 3.0ms preprocess, 213.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 248.6ms
# Speed: 2.0ms preprocess, 248.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 214.1ms
# Speed: 2.0ms preprocess, 214.1ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 223.1ms
# Speed: 3.0ms preprocess, 223.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 224.6ms
# Speed: 3.0ms preprocess, 224.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 211.1ms
# Speed: 3.0ms preprocess, 211.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 193.1ms
# Speed: 3.0ms preprocess, 193.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 200.1ms
# Speed: 2.0ms preprocess, 200.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 210.0ms
# Speed: 3.0ms preprocess, 210.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 225.0ms
# Speed: 3.0ms preprocess, 225.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 212.1ms
# Speed: 3.0ms preprocess, 212.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 205.7ms
# Speed: 3.0ms preprocess, 205.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 201.1ms
# Speed: 3.0ms preprocess, 201.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 214.1ms
# Speed: 2.0ms preprocess, 214.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 216.6ms
# Speed: 4.0ms preprocess, 216.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 254.1ms
# Speed: 3.0ms preprocess, 254.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 230.6ms
# Speed: 2.0ms preprocess, 230.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 257.7ms
# Speed: 3.0ms preprocess, 257.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 212.1ms
# Speed: 3.0ms preprocess, 212.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 196.1ms
# Speed: 3.0ms preprocess, 196.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 216.1ms
# Speed: 3.0ms preprocess, 216.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 215.1ms
# Speed: 3.0ms preprocess, 215.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 233.2ms
# Speed: 3.0ms preprocess, 233.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 231.6ms
# Speed: 3.0ms preprocess, 231.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 222.1ms
# Speed: 3.0ms preprocess, 222.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 202.1ms
# Speed: 3.0ms preprocess, 202.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 207.6ms
# Speed: 2.0ms preprocess, 207.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 204.1ms
# Speed: 2.0ms preprocess, 204.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 227.1ms
# Speed: 3.0ms preprocess, 227.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 199.1ms
# Speed: 3.0ms preprocess, 199.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 202.1ms
# Speed: 3.0ms preprocess, 202.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 201.1ms
# Speed: 2.0ms preprocess, 201.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 202.1ms
# Speed: 3.0ms preprocess, 202.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 208.1ms
# Speed: 5.0ms preprocess, 208.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 216.7ms
# Speed: 3.0ms preprocess, 216.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 196.0ms
# Speed: 3.0ms preprocess, 196.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 207.1ms
# Speed: 3.0ms preprocess, 207.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 207.1ms
# Speed: 4.0ms preprocess, 207.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 204.2ms
# Speed: 3.0ms preprocess, 204.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 202.1ms
# Speed: 3.0ms preprocess, 202.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 234.1ms
# Speed: 2.0ms preprocess, 234.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 218.1ms
# Speed: 3.0ms preprocess, 218.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 199.1ms
# Speed: 2.0ms preprocess, 199.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 208.1ms
# Speed: 3.0ms preprocess, 208.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 204.1ms
# Speed: 2.5ms preprocess, 204.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 212.7ms
# Speed: 3.0ms preprocess, 212.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 214.2ms
# Speed: 3.0ms preprocess, 214.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 199.2ms
# Speed: 3.0ms preprocess, 199.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 206.6ms
# Speed: 4.0ms preprocess, 206.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 201.0ms
# Speed: 2.0ms preprocess, 201.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 236.0ms
# Speed: 3.0ms preprocess, 236.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 202.1ms
# Speed: 2.0ms preprocess, 202.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 211.1ms
# Speed: 2.0ms preprocess, 211.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 209.0ms
# Speed: 2.0ms preprocess, 209.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 207.1ms
# Speed: 3.0ms preprocess, 207.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 226.6ms
# Speed: 3.0ms preprocess, 226.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 220.2ms
# Speed: 2.0ms preprocess, 220.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 243.6ms
# Speed: 3.0ms preprocess, 243.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 247.0ms
# Speed: 2.0ms preprocess, 247.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 253.0ms
# Speed: 3.0ms preprocess, 253.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 283.6ms
# Speed: 2.0ms preprocess, 283.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 250.6ms
# Speed: 3.0ms preprocess, 250.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 257.4ms
# Speed: 3.0ms preprocess, 257.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 265.6ms
# Speed: 3.0ms preprocess, 265.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 243.1ms
# Speed: 3.0ms preprocess, 243.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 255.6ms
# Speed: 3.0ms preprocess, 255.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 254.1ms
# Speed: 3.0ms preprocess, 254.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 257.0ms
# Speed: 3.0ms preprocess, 257.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 247.7ms
# Speed: 2.0ms preprocess, 247.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 216.5ms
# Speed: 3.0ms preprocess, 216.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 234.6ms
# Speed: 3.0ms preprocess, 234.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 213.0ms
# Speed: 3.0ms preprocess, 213.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 212.1ms
# Speed: 3.0ms preprocess, 212.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 209.2ms
# Speed: 3.0ms preprocess, 209.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 207.0ms
# Speed: 3.0ms preprocess, 207.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 212.2ms
# Speed: 2.0ms preprocess, 212.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 208.0ms
# Speed: 2.0ms preprocess, 208.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 210.6ms
# Speed: 3.0ms preprocess, 210.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 214.1ms
# Speed: 2.0ms preprocess, 214.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 234.9ms
# Speed: 3.0ms preprocess, 234.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 199.0ms
# Speed: 3.0ms preprocess, 199.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 228.3ms
# Speed: 2.0ms preprocess, 228.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 217.0ms
# Speed: 3.0ms preprocess, 217.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 213.1ms
# Speed: 3.0ms preprocess, 213.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 210.1ms
# Speed: 3.0ms preprocess, 210.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 251.2ms
# Speed: 3.0ms preprocess, 251.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 232.1ms
# Speed: 3.0ms preprocess, 232.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 207.1ms
# Speed: 2.5ms preprocess, 207.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 235.6ms
# Speed: 3.0ms preprocess, 235.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 215.7ms
# Speed: 2.0ms preprocess, 215.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 220.1ms
# Speed: 3.0ms preprocess, 220.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 216.2ms
# Speed: 5.0ms preprocess, 216.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 214.1ms
# Speed: 3.0ms preprocess, 214.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 222.0ms
# Speed: 2.0ms preprocess, 222.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 215.1ms
# Speed: 4.0ms preprocess, 215.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 212.6ms
# Speed: 3.0ms preprocess, 212.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 230.2ms
# Speed: 3.0ms preprocess, 230.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 203.1ms
# Speed: 3.0ms preprocess, 203.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 204.0ms
# Speed: 2.0ms preprocess, 204.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 201.1ms
# Speed: 3.0ms preprocess, 201.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 208.2ms
# Speed: 4.0ms preprocess, 208.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 198.1ms
# Speed: 2.0ms preprocess, 198.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 206.1ms
# Speed: 3.0ms preprocess, 206.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 203.1ms
# Speed: 2.0ms preprocess, 203.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 236.1ms
# Speed: 3.0ms preprocess, 236.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 211.1ms
# Speed: 3.5ms preprocess, 211.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 201.3ms
# Speed: 2.0ms preprocess, 201.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 200.1ms
# Speed: 2.0ms preprocess, 200.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 200.1ms
# Speed: 2.0ms preprocess, 200.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 200.1ms
# Speed: 2.0ms preprocess, 200.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 210.0ms
# Speed: 3.0ms preprocess, 210.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 202.1ms
# Speed: 2.0ms preprocess, 202.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 232.6ms
# Speed: 3.0ms preprocess, 232.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 209.6ms
# Speed: 2.0ms preprocess, 209.6ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 202.1ms
# Speed: 3.0ms preprocess, 202.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 205.1ms
# Speed: 3.0ms preprocess, 205.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 205.1ms
# Speed: 3.0ms preprocess, 205.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 208.1ms
# Speed: 3.0ms preprocess, 208.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 206.1ms
# Speed: 2.0ms preprocess, 206.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 203.1ms
# Speed: 3.0ms preprocess, 203.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 239.0ms
# Speed: 2.0ms preprocess, 239.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 211.1ms
# Speed: 3.0ms preprocess, 211.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 230.1ms
# Speed: 2.0ms preprocess, 230.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 227.1ms
# Speed: 2.0ms preprocess, 227.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 226.1ms
# Speed: 3.0ms preprocess, 226.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 227.2ms
# Speed: 3.0ms preprocess, 227.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 240.6ms
# Speed: 3.0ms preprocess, 240.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 241.7ms
# Speed: 3.0ms preprocess, 241.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 219.0ms
# Speed: 5.0ms preprocess, 219.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 232.6ms
# Speed: 2.0ms preprocess, 232.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 247.1ms
# Speed: 3.0ms preprocess, 247.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 247.6ms
# Speed: 3.0ms preprocess, 247.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 234.1ms
# Speed: 3.0ms preprocess, 234.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 258.7ms
# Speed: 3.0ms preprocess, 258.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 229.0ms
# Speed: 3.0ms preprocess, 229.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 223.1ms
# Speed: 2.0ms preprocess, 223.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 239.2ms
# Speed: 2.0ms preprocess, 239.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 227.1ms
# Speed: 3.0ms preprocess, 227.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 213.7ms
# Speed: 3.5ms preprocess, 213.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 217.1ms
# Speed: 3.0ms preprocess, 217.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 232.6ms
# Speed: 3.0ms preprocess, 232.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 213.7ms
# Speed: 2.0ms preprocess, 213.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 203.8ms
# Speed: 3.0ms preprocess, 203.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 214.0ms
# Speed: 3.0ms preprocess, 214.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 217.1ms
# Speed: 2.0ms preprocess, 217.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 211.1ms
# Speed: 2.0ms preprocess, 211.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 202.9ms
# Speed: 3.0ms preprocess, 202.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 264.6ms
# Speed: 3.0ms preprocess, 264.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 273.3ms
# Speed: 3.5ms preprocess, 273.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 230.6ms
# Speed: 3.0ms preprocess, 230.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 232.0ms
# Speed: 3.0ms preprocess, 232.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 238.6ms
# Speed: 3.0ms preprocess, 238.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 238.1ms
# Speed: 4.0ms preprocess, 238.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 207.1ms
# Speed: 2.0ms preprocess, 207.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 250.1ms
# Speed: 2.0ms preprocess, 250.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 222.6ms
# Speed: 3.0ms preprocess, 222.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 214.1ms
# Speed: 3.0ms preprocess, 214.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 226.1ms
# Speed: 3.0ms preprocess, 226.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 215.1ms
# Speed: 4.0ms preprocess, 215.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 207.0ms
# Speed: 3.0ms preprocess, 207.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 201.0ms
# Speed: 4.0ms preprocess, 201.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 237.6ms
# Speed: 2.0ms preprocess, 237.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 206.1ms
# Speed: 3.0ms preprocess, 206.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 202.1ms
# Speed: 2.0ms preprocess, 202.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 205.3ms
# Speed: 2.0ms preprocess, 205.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 200.1ms
# Speed: 2.0ms preprocess, 200.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 204.1ms
# Speed: 3.0ms preprocess, 204.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 227.0ms
# Speed: 2.0ms preprocess, 227.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 212.7ms
# Speed: 3.0ms preprocess, 212.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 213.0ms
# Speed: 2.0ms preprocess, 213.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 212.2ms
# Speed: 3.0ms preprocess, 212.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 206.1ms
# Speed: 3.0ms preprocess, 206.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 208.6ms
# Speed: 3.0ms preprocess, 208.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 236.1ms
# Speed: 2.0ms preprocess, 236.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 202.6ms
# Speed: 3.0ms preprocess, 202.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 203.2ms
# Speed: 3.0ms preprocess, 203.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 206.1ms
# Speed: 3.0ms preprocess, 206.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 201.6ms
# Speed: 3.0ms preprocess, 201.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 201.1ms
# Speed: 2.0ms preprocess, 201.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 253.1ms
# Speed: 2.0ms preprocess, 253.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 207.1ms
# Speed: 2.0ms preprocess, 207.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 204.7ms
# Speed: 3.0ms preprocess, 204.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 206.1ms
# Speed: 3.0ms preprocess, 206.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 210.1ms
# Speed: 3.0ms preprocess, 210.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 207.1ms
# Speed: 3.0ms preprocess, 207.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 237.6ms
# Speed: 3.0ms preprocess, 237.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 205.1ms
# Speed: 2.0ms preprocess, 205.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 208.1ms
# Speed: 3.0ms preprocess, 208.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 238.3ms
# Speed: 3.0ms preprocess, 238.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 237.7ms
# Speed: 3.0ms preprocess, 237.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 225.1ms
# Speed: 3.0ms preprocess, 225.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 246.9ms
# Speed: 3.0ms preprocess, 246.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 229.1ms
# Speed: 3.0ms preprocess, 229.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 224.1ms
# Speed: 3.0ms preprocess, 224.1ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 220.1ms
# Speed: 4.0ms preprocess, 220.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 222.5ms
# Speed: 3.0ms preprocess, 222.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 232.1ms
# Speed: 3.5ms preprocess, 232.1ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 255.6ms
# Speed: 3.0ms preprocess, 255.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 219.1ms
# Speed: 3.0ms preprocess, 219.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 217.6ms
# Speed: 3.0ms preprocess, 217.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 216.6ms
# Speed: 2.0ms preprocess, 216.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 231.1ms
# Speed: 2.0ms preprocess, 231.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 208.1ms
# Speed: 3.0ms preprocess, 208.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 248.1ms
# Speed: 3.0ms preprocess, 248.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 229.0ms
# Speed: 2.0ms preprocess, 229.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 225.1ms
# Speed: 2.0ms preprocess, 225.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 241.6ms
# Speed: 3.0ms preprocess, 241.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 215.1ms
# Speed: 2.0ms preprocess, 215.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 236.1ms
# Speed: 3.0ms preprocess, 236.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 209.1ms
# Speed: 5.0ms preprocess, 209.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 249.2ms
# Speed: 3.0ms preprocess, 249.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 229.1ms
# Speed: 3.0ms preprocess, 229.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 218.6ms
# Speed: 3.0ms preprocess, 218.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 222.2ms
# Speed: 2.1ms preprocess, 222.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 230.6ms
# Speed: 3.0ms preprocess, 230.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 230.6ms
# Speed: 3.0ms preprocess, 230.6ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 227.6ms
# Speed: 3.0ms preprocess, 227.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 218.0ms
# Speed: 3.0ms preprocess, 218.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 251.6ms
# Speed: 2.0ms preprocess, 251.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 244.1ms
# Speed: 3.0ms preprocess, 244.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 213.1ms
# Speed: 2.5ms preprocess, 213.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 215.8ms
# Speed: 3.0ms preprocess, 215.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 204.1ms
# Speed: 3.0ms preprocess, 204.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 226.6ms
# Speed: 3.0ms preprocess, 226.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 202.9ms
# Speed: 2.0ms preprocess, 202.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 204.1ms
# Speed: 2.0ms preprocess, 204.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 209.1ms
# Speed: 2.0ms preprocess, 209.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 205.1ms
# Speed: 3.0ms preprocess, 205.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 240.1ms
# Speed: 2.0ms preprocess, 240.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 209.1ms
# Speed: 2.0ms preprocess, 209.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 205.1ms
# Speed: 3.0ms preprocess, 205.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 202.1ms
# Speed: 3.0ms preprocess, 202.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 209.1ms
# Speed: 3.0ms preprocess, 209.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 233.7ms
# Speed: 2.5ms preprocess, 233.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 208.1ms
# Speed: 2.0ms preprocess, 208.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 207.1ms
# Speed: 3.0ms preprocess, 207.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 206.1ms
# Speed: 2.0ms preprocess, 206.1ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 207.1ms
# Speed: 2.0ms preprocess, 207.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 237.1ms
# Speed: 3.0ms preprocess, 237.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 209.1ms
# Speed: 2.0ms preprocess, 209.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 205.1ms
# Speed: 3.0ms preprocess, 205.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 209.1ms
# Speed: 2.0ms preprocess, 209.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 203.7ms
# Speed: 3.0ms preprocess, 203.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 229.6ms
# Speed: 4.0ms preprocess, 229.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 205.1ms
# Speed: 3.0ms preprocess, 205.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 205.1ms
# Speed: 1.3ms preprocess, 205.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 208.1ms
# Speed: 2.0ms preprocess, 208.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 210.6ms
# Speed: 2.0ms preprocess, 210.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 238.1ms
# Speed: 3.0ms preprocess, 238.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 208.0ms
# Speed: 3.0ms preprocess, 208.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 210.1ms
# Speed: 2.0ms preprocess, 210.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 218.6ms
# Speed: 2.0ms preprocess, 218.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 220.1ms
# Speed: 3.0ms preprocess, 220.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 243.1ms
# Speed: 3.0ms preprocess, 243.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 215.1ms
# Speed: 3.0ms preprocess, 215.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 235.1ms
# Speed: 3.0ms preprocess, 235.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 241.7ms
# Speed: 3.0ms preprocess, 241.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 233.1ms
# Speed: 3.0ms preprocess, 233.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 252.1ms
# Speed: 3.0ms preprocess, 252.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 229.7ms
# Speed: 5.0ms preprocess, 229.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 231.1ms
# Speed: 3.0ms preprocess, 231.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 241.8ms
# Speed: 2.0ms preprocess, 241.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 223.1ms
# Speed: 2.0ms preprocess, 223.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 266.3ms
# Speed: 2.0ms preprocess, 266.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 250.6ms
# ...
#
# 0: 480x640 1 person, 1 chair, 190.1ms
# Speed: 3.0ms preprocess, 190.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 193.1ms
# Speed: 3.0ms preprocess, 193.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 193.5ms
# Speed: 3.0ms preprocess, 193.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 193.0ms
# Speed: 3.0ms preprocess, 193.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 265.7ms
# Speed: 5.0ms preprocess, 265.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 194.1ms
# Speed: 2.0ms preprocess, 194.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 188.1ms
# Speed: 2.0ms preprocess, 188.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 202.1ms
# Speed: 2.0ms preprocess, 202.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 201.1ms
# Speed: 3.0ms preprocess, 201.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 197.5ms
# Speed: 2.0ms preprocess, 197.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 227.1ms
# Speed: 2.0ms preprocess, 227.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 274.6ms
# Speed: 2.0ms preprocess, 274.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 249.6ms
# Speed: 3.0ms preprocess, 249.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 250.4ms
# Speed: 3.0ms preprocess, 250.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 241.1ms
# Speed: 3.0ms preprocess, 241.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 245.6ms
# Speed: 3.0ms preprocess, 245.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 236.1ms
# Speed: 3.0ms preprocess, 236.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 242.8ms
# Speed: 3.0ms preprocess, 242.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 260.6ms
# Speed: 3.0ms preprocess, 260.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 260.6ms
# Speed: 2.0ms preprocess, 260.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 250.1ms
# Speed: 3.0ms preprocess, 250.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 244.6ms
# Speed: 2.0ms preprocess, 244.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 225.0ms
# Speed: 3.0ms preprocess, 225.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 245.1ms
# Speed: 2.0ms preprocess, 245.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 249.6ms
# Speed: 3.0ms preprocess, 249.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 241.1ms
# Speed: 3.0ms preprocess, 241.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 216.1ms
# Speed: 3.0ms preprocess, 216.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 194.1ms
# Speed: 3.0ms preprocess, 194.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 187.2ms
# Speed: 3.0ms preprocess, 187.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 202.1ms
# Speed: 3.0ms preprocess, 202.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 205.1ms
# Speed: 2.0ms preprocess, 205.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 200.0ms
# Speed: 2.0ms preprocess, 200.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 191.1ms
# Speed: 2.0ms preprocess, 191.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 184.1ms
# Speed: 3.0ms preprocess, 184.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 201.6ms
# Speed: 3.0ms preprocess, 201.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 198.1ms
# Speed: 2.0ms preprocess, 198.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 278.7ms
# Speed: 7.0ms preprocess, 278.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 191.1ms
# Speed: 1.5ms preprocess, 191.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 213.1ms
# Speed: 3.0ms preprocess, 213.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 201.1ms
# Speed: 2.0ms preprocess, 201.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 194.6ms
# Speed: 3.0ms preprocess, 194.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 195.0ms
# Speed: 2.0ms preprocess, 195.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 193.1ms
# Speed: 2.0ms preprocess, 193.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 284.8ms
# Speed: 6.0ms preprocess, 284.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 196.1ms
# Speed: 2.0ms preprocess, 196.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 260.8ms
# Speed: 5.9ms preprocess, 260.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 bed, 194.1ms
# Speed: 2.0ms preprocess, 194.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 187.0ms
# Speed: 3.0ms preprocess, 187.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 185.1ms
# Speed: 3.0ms preprocess, 185.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 195.1ms
# Speed: 2.0ms preprocess, 195.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 261.6ms
# Speed: 6.9ms preprocess, 261.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 198.1ms
# Speed: 2.0ms preprocess, 198.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 188.0ms
# Speed: 2.0ms preprocess, 188.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 191.0ms
# Speed: 2.0ms preprocess, 191.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 195.1ms
# Speed: 3.0ms preprocess, 195.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 221.6ms
# Speed: 5.0ms preprocess, 221.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 horse, 1 chair, 194.1ms
# Speed: 2.0ms preprocess, 194.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 192.0ms
# Speed: 2.0ms preprocess, 192.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 197.1ms
# Speed: 2.0ms preprocess, 197.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 218.2ms
# Speed: 2.0ms preprocess, 218.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 239.6ms
# Speed: 3.0ms preprocess, 239.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 227.1ms
# Speed: 2.0ms preprocess, 227.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 248.1ms
# Speed: 3.0ms preprocess, 248.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 246.6ms
# Speed: 3.0ms preprocess, 246.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 236.6ms
# Speed: 5.0ms preprocess, 236.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 231.6ms
# Speed: 3.0ms preprocess, 231.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 244.1ms
# Speed: 3.0ms preprocess, 244.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 238.1ms
# Speed: 3.0ms preprocess, 238.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 240.0ms
# Speed: 3.0ms preprocess, 240.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 245.6ms
# Speed: 5.0ms preprocess, 245.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 249.1ms
# Speed: 3.0ms preprocess, 249.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 194.5ms
# Speed: 2.0ms preprocess, 194.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 254.0ms
# Speed: 3.0ms preprocess, 254.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 259.1ms
# Speed: 3.0ms preprocess, 259.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 235.6ms
# Speed: 2.0ms preprocess, 235.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 223.8ms
# Speed: 2.0ms preprocess, 223.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 276.6ms
# Speed: 2.0ms preprocess, 276.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 225.6ms
# Speed: 3.0ms preprocess, 225.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 200.0ms
# Speed: 2.0ms preprocess, 200.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 194.1ms
# Speed: 2.0ms preprocess, 194.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 222.2ms
# Speed: 2.0ms preprocess, 222.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 201.0ms
# Speed: 3.0ms preprocess, 201.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 194.6ms
# Speed: 2.0ms preprocess, 194.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 192.1ms
# Speed: 2.0ms preprocess, 192.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 257.1ms
# Speed: 6.5ms preprocess, 257.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 194.0ms
# Speed: 2.0ms preprocess, 194.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 188.1ms
# Speed: 2.0ms preprocess, 188.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 259.8ms
# Speed: 5.9ms preprocess, 259.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 190.0ms
# Speed: 3.0ms preprocess, 190.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 193.0ms
# Speed: 3.0ms preprocess, 193.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 187.1ms
# Speed: 3.0ms preprocess, 187.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 194.1ms
# Speed: 2.0ms preprocess, 194.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 200.1ms
# Speed: 4.0ms preprocess, 200.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 188.0ms
# Speed: 2.0ms preprocess, 188.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 193.3ms
# Speed: 3.0ms preprocess, 193.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 257.7ms
# Speed: 6.0ms preprocess, 257.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 188.6ms
# Speed: 2.0ms preprocess, 188.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 207.0ms
# Speed: 2.0ms preprocess, 207.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 191.0ms
# Speed: 3.0ms preprocess, 191.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 216.5ms
# Speed: 2.0ms preprocess, 216.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 192.1ms
# Speed: 2.0ms preprocess, 192.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 191.2ms
# Speed: 3.0ms preprocess, 191.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 198.1ms
# Speed: 3.0ms preprocess, 198.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 191.0ms
# Speed: 2.0ms preprocess, 191.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 254.2ms
# Speed: 2.0ms preprocess, 254.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 229.1ms
# Speed: 2.0ms preprocess, 229.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 286.2ms
# Speed: 4.0ms preprocess, 286.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 289.7ms
# Speed: 3.0ms preprocess, 289.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 291.2ms
# Speed: 3.0ms preprocess, 291.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 297.3ms
# Speed: 4.0ms preprocess, 297.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 296.8ms
# Speed: 3.0ms preprocess, 296.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 284.0ms
# Speed: 2.0ms preprocess, 284.0ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 262.3ms
# Speed: 3.3ms preprocess, 262.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 279.8ms
# Speed: 3.2ms preprocess, 279.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 580.5ms
# Speed: 4.1ms preprocess, 580.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 705.2ms
# Speed: 11.5ms preprocess, 705.2ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 589.2ms
# Speed: 3.0ms preprocess, 589.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1118.7ms
# Speed: 3.0ms preprocess, 1118.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
